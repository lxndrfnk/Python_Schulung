# %%
import pandas as pd

df = pd.read_excel("Garmin_Daten_bereinigt.xlsx")

df
# Out:
#                  Datum  Temp. [Max.]  Temp. [Min.]  Durchschnittstemperatur  \
# 0  2025-03-09 06:57:00          19.2           2.4                    10.80
# 1  2025-03-30 14:09:00          13.6           5.1                     9.35
# 2  2025-04-10 09:19:00          14.3           5.8                    10.05
# 3  2025-02-19 12:10:00           5.5          -1.2                     2.15
# 4  2025-03-01 07:56:00           5.3          -0.3                     2.50
# 5  2025-06-03 17:50:00          23.8           9.3                    16.55
# 6  2025-03-23 10:31:00          16.1           0.8                     8.45
# 7  2025-03-13 09:54:00           7.6          -0.1                     3.75
# 8  2025-05-01 12:27:00          28.5           9.9                    19.20
# 9  2025-02-16 10:44:00           4.8          -0.1                     2.35
# 10 2025-02-10 11:27:00           0.4           1.3                     0.85
# ...
